# %%
#Problem 1: Unique Words in a Sentence Problem Statement Given a sentence, identify all unique words and display: The count of unique words The unique words themselves

# %%
sentence = input("Enter sentence: ")
words = sentence.split()
unique_words = set(words)

print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Enter sentence:  python is easy and python is powerful
# Unique words count: 5
# Unique words: {'powerful', 'python', 'and', 'is', 'easy'}

# %%
#Problem 2: Highest Salary from Employee Data Problem Statement Store employee names and their salaries, and determine which employee has the highest salary.

# %%
employees = {
    "Alisha": 75000,
    "Rutuja": 68000,
    "Aarti": 72000
}

max_employee = max(employees, key=employees.get)
max_salary = employees[max_employee]

print("Highest Salary:", max_employee, "-", max_salary)
# Out:
# Highest Salary: Alisha - 75000

# %%
#Problem 3: Find Maximum and Minimum Values Problem Statement Find the maximum and minimum values from a list of numbers.

# %%
numbers = [45, 22, 89, 10, 66]
max_val = numbers[0]
min_val = numbers[0]

for num in numbers:
    if num > max_val:
        max_val = num
    if num < min_val:
        min_val = num

print("List:", numbers)
print("Max:", max_val)
print("Min:", min_val)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
#Problem 4: Count Products Above a Price Threshold Problem Statement Count how many products have a price greater than 1000.

# %%
prices = [450, 1200, 899, 1500, 300]
count = 0

for price in prices:
    if price > 1000:
        count += 1
print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %%
#Problem 5: Calculate Attendance Percentage Problem Statement #Calculate the attendance percentage from a list containing "P" (Present) and "A" (Absent).

# %%
attendance = ["P", "P", "A", "P", "P"]
present_count = attendance.count("P")
total_days = len(attendance)
percentage = (present_count / total_days) * 100
print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %%
#Problem 6: Remove Duplicate Phone Numbers Problem Statement You are given a list of phone numbers that may contain duplicates. Write a Python program to remove duplicate phone numbers and display only the unique phone numbers.

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]
unique_numbers = set(phone_numbers)
print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %%
#Problem 7: Count Character Frequency Problem Statement Count how many times each character appears in a given string.

# %%
text = "python"
frequency = {}
for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1
print(frequency)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
#Problem 8: Convert List to Tuple Problem Statement Convert a list into a tuple and display it.

# %%
my_list = [10, 20, 30]
my_tuple = tuple(my_list)
print("Tuple:", my_tuple)
# Out:
# Tuple: (10, 20, 30)

# %%
#Problem 9: Check if a Key Exists in a Dictionary Problem Statement Check whether a specific key exists in a dictionary.

# %%
employees = {
    "Alisha": 75000,
    "Aarti": 68000}
key = "Alisha"
if key in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %%
#Problem 10: Calculate Average Marks Problem Statement Calculate the average marks of a student from a list of marks.

# %%
marks = [70, 80, 65, 75]
total = sum(marks)
count = len(marks)
average = total / count
print("Average Marks:", average)
# Out:
# Average Marks: 72.5

# %% [markdown]
# All tasks were completed successfully.
# This notebook demonstrates basic Python logic-building skills using:
# Conditional statements
# Loops
# String manipulation
# Data cleaning techniques
# Basic data/log analysis
